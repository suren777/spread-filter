# %%
from price_generator import  generate_path
import numpy as np
import matplotlib.pyplot as plt

# %%
x0, alpha, lmbd, sigma, kappa, dt = 4, 0.09, 0.37, 0.43, 0.03, 1/252.
c1,c2,c3,c4 = 1.2,-0.19,0.1,-0.34
eta = 0.01
n_steps = 252
Tn=[0.3]
price_path = generate_path(x0, alpha, lmbd, sigma, kappa, dt, Tn, c1, c2, c3, c4, eta, n_steps)
plt.plot(price_path[0].T,label='Spot')
plt.plot(price_path[1].T)
plt.legend()

# %%
var = sigma * sigma / (2 * kappa) * (1 - np.exp(-2 * kappa * dt))
var
# Out:
# 0.0007336428168338869

# %%
 np.exp(-2 * 5 * dt)
# Out:
# 0.9610945000924984
